# %% [markdown]
# # Attempting to Understand Fourier Features

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb
from statsmodels.tsa.deterministic import (CalendarFourier,
                                           CalendarSeasonality,
                                           CalendarTimeTrend,
                                           DeterministicProcess)

# %%
date_range = pd.date_range('2018-01-01', '2018-03-01')
test = pd.DataFrame({'date': date_range})

fourier_terms = CalendarFourier(freq='W', order=1)
df_fourier = fourier_terms.in_sample(test['date'])

# %%
df_fourier['date'] = date_range
df_fourier.plot(x='date')
# Out:
# <Axes: xlabel='date'>

# %%
df_fourier.head()
# Out:
#             sin(1,freq=ME)  cos(1,freq=ME)       date
# date
# 2018-01-01        0.000000        1.000000 2018-01-01
# 2018-01-02        0.201299        0.979530 2018-01-02
# 2018-01-03        0.394356        0.918958 2018-01-03
# 2018-01-04        0.571268        0.820763 2018-01-04
# 2018-01-05        0.724793        0.688967 2018-01-05
